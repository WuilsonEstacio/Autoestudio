# %%
# TAREA SUBATOMICA
import numpy as np   # funciones numéricas (arrays, matrices, etc.)
import math as m          # para la libreria de matatematicas
import matplotlib.pyplot as plt # para poder ver graficas


V_R= 200* m.e**(-1.487*r*r)
V_t= -178* m.e**(-0.639*r*r)
V_s= -91.85* m.e**(-0.465*r*r)
u=1
Psigma = -1# np.array([-1.0, -1.0, -1.0])
Pr  = -1 # np.array([-1.0,-1.0, -1.0] )
taui = -5 # np.array([-0.5,0.5,-0.5])
tauj = 5 # np.array([-0.5,0.5,0.5])
inte = 4 # ['n-n','p-p','n-p']

def f(r):
      return ((V_R+(0.5)*(1+Psigma)*V_t +(0.5)*(1-Psigma)*V_s ) * ((0.5)*u + (0.5)*(2-u)*Pr) + (0.5)*(1+taui)*(0.5)*(1+tauj)*(m.e**2)//r)
r = np.array([0.01, 1, 2, 4, 8, 16, 36, 64, 128, 256, 512 ])      
y = f(r)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1811a87a9e0a> in <module>()
#       5
#       6
# ----> 7 V_R= 200* m.e**(-1.487*r*r)
#       8 V_t= -178* m.e**(-0.639*r*r)
#       9 V_s= -91.85* m.e**(-0.465*r*r)
#
# NameError: name 'r' is not defined

# %%
import pandas as pd

tabla = pd.DataFrame( list(zip(r, y)), columns=['r', 'f(r)'] )
tabla
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e221de365d5> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 tabla = pd.DataFrame( list(zip(r, y)), columns=['r', 'f(r)'] )
#       4 tabla
#
# NameError: name 'r' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np   # funciones numéricas (arrays, matrices, etc.)
import math as m          # para la libreria de matatematicas

r = np.linspace(0, 5, 100)



plt.plot(r, f(r) )  # Trace algunos datos en los ejes (implícitos).

plt.xlabel('r')  # Agregue una etiqueta x a los ejes
plt.ylabel('f(r)')  # Agregue una etiqueta y a los ejes
plt.title("Grafico de f(r)")
plt.legend()
ax = move_spines()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in floor_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-55e1bba9bcd3> in <module>()
#       7
#       8
# ----> 9 plt.plot(r, f(r) )  # Trace algunos datos en los ejes (implícitos).
#      10
#      11 plt.xlabel('r')  # Agregue una etiqueta x a los ejes
#
# <ipython-input-10-1811a87a9e0a> in f(r)
#      16
#      17 def f(r):
# ---> 18       return ((V_R+(0.5)*(1+Psigma)*V_t +(0.5)*(1-Psigma)*V_s ) * ((0.5)*u + (0.5)*(2-u)*Pr) + (0.5)*(1+taui)*(0.5)*(1+tauj)*(m.e**2)//r)
#      19 r = np.array([0.01, 1, 2, 4, 8, 16, 36, 64, 128, 256, 512 ])
#      20 y = f(r)
#
# ValueError: operands could not be broadcast together with shapes (11,) (100,)

# %%
# TAREA SUBATOMICA
import numpy as np   # funciones numéricas (arrays, matrices, etc.)
import math as m          # para la libreria de matatematicas
import matplotlib.pyplot as plt # para poder ver graficas

# variab

V_R= 200* m.e**(-1.487*r*r)
V_t= -178* m.e**(-0.639*r*r)
V_s= -91.85* m.e**(-0.465*r*r)
u=1
Psigma = np.array([-1.0, -1.0, -1.0])
Pr  =  np.array([-1.0,-1.0, -1.0] )
taui = np.array([-0.5,0.5,-0.5])
tauj = np.array([-0.5,0.5,0.5])
inte = ['n-n','p-p','n-p']

for i in range(len(Psigma)):
      V1 =  ((V_R+(0.5)*(1+Psigma[i])*V_t +(0.5)*(1-Psigma[i])*V_s ) * ((0.5)*u + (0.5)*(2-u)*Pr[i]) + (0.5)*(1+taui[i])*(0.5)*(1+tauj[i])*(m.e**2)//r)
      a = inte[i]
      print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0b97c0671e28> in <module>()
#       6 # variab
#       7
# ----> 8 V_R= 200* m.e**(-1.487*r*r)
#       9 V_t= -178* m.e**(-0.639*r*r)
#      10 V_s= -91.85* m.e**(-0.465*r*r)
#
# NameError: name 'r' is not defined

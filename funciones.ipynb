# %%
import numpy as np  

def f(x):
    return np.sqrt(x + 2)
x = np.array([-2, -1, 0, 2, 4, 6]) 
y = f(x)
print(y)
# Out:
# [0.         1.         1.41421356 2.         2.44948974 2.82842712]

# %%
import pandas as pd

tabla = pd.DataFrame( list(zip(x, y)), columns=['x', 'f(x)'] )
tabla
# Out:
#    x      f(x)
# 0 -2  0.000000
# 1 -1  1.000000
# 2  0  1.414214
# 3  2  2.000000
# 4  4  2.449490
# 5  6  2.828427

# %%
#matplotlib inline

import matplotlib.pyplot as plt

def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots()
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

x = np.linspace(-2, 10, num=30)


ax = move_spines()
ax.grid()
ax.plot(x, f(x))
plt.title(r"Grafico de $f(x)=\sqrt{x + 2}$")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

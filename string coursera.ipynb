# %%
name="Wuilson"
"hola %s " % name  # %s interpreta a la variable name como un string
# Out:
# 'hola Wuilson '

# %%
" ".join(["hola", name]) #
# Out:
# 'hola Wuilson'

# %%
"el decimal es %f" % 6.5  # %f interpreta como un decimal
# Out:
# 'el decimal es 6.500000'

# %%
"el numero es %0.2d" % 6   #
# Out:
# 'el numero es 06'

# %%
"el numero es %d" % 5    # %d interpreta como un entero
# Out:
# 'el numero es 5'

# %%
"hola {}".format(name)
# Out:
# 'hola Wuilson'

# %%
name.count('u')  # Devuelve la cantidad de veces que aparece un substring en el string
# Out:
# 1

# %%
'prueba para la u'.index('u') # Busca el substring pasado como parámetro en el string y devuelve el primer
# índice donde lo encontró o ValueError en caso de no encontrarlo.
# Out:
# 2

# %%
name.encode('utf-8')  # Codifica un string con cierta codificación
# Out:
# b'Wuilson'

# %%
'prueba'.capitalize() # capitaliza
# Out:
# 'Prueba'

# %%
'prueba10'.isalnum() # Indica si el string contiene solo caracteres alfanumérico.
# Out:
# True

# %%
'Prueba'.istitle()  # Indica si el string tiene las mayúsculas y minúsculas con formato de título
# Out:
# True

# %%
name.lower()  # Genera un nuevo string con todas las letras en minúsculas.
# Out:
# 'wuilson'

# %%
'Prueba'.upper()  # Genera un nuevo string con todas las letras en mayuscula.
# Out:
# 'PRUEBA'

# %%
'Prueba'.swapcase() # Intercambia las mayúsculas por las minúsculas y viceversa.
# Out:
# 'pRUEBA'

# %%
'prueba'.title() # Genera un string con el mismo contenido pero con formato título
# (primera letra de cada palabra en mayúscula)
# Out:
# 'Prueba'

# %%
name.replace('W', 'g') # Reemplaza las apariciones del substring del primer parámetro por el substring del segundo parámetro.
# Out:
# 'guilson'

# %%
'prueba'.rjust(10) # justifica la cadena da caracteres  a la derecha con tantos espacios como se indiquen en este caso 10
# Out:
# '    prueba'

# %%
'prueba'.ljust(10) # justifica la cadena da caracteres  a la izquierda con tantos espacios como se indiquen en este caso 10
# Out:
# 'prueba    '

# %%
'prueba'.center(10)  # centra la cadena de caracteres
# Out:
# '  prueba  '

# %%
'Prueba'.startswith('P') # Indica si el string comienza con el substring pasado como parámetro.
# Out:
# True

# %%
print('\'Hola \n Mundo!\'')
# Out:
# 'Hola
#  Mundo!'

# %%
'py'.capitalize().startswith('P')
# Out:
# True

# %%
'py'.lower().startswith('P')
# Out:
# False

# %%
'prueb'.endswith('a')
# Out:
# False

# %%
''.isspace()
# Out:
# False

# %%
'Este es Un Titulo'.istitle()
# Out:
# False

# %%
'1, 2, 3, 4'.split(',')
# Out:
# ['1', ' 2', ' 3', ' 4']

# %%
'PYTHON3!'.isupper()
# Out:
# True

# %%
try:
  print(1)
  assert 2+2 ==5
except AssertionError:
  print(3)
except:
  pritn(4)
# Out:
# 1
# 3

# %%
p={1:2,2:3,4:7,7:17}
print(p[p[4]])
# Out:
# 17

# %%
p={1:1,2:1,3:2,4:3}
print(p.get(7,9))
print(p.get(4,0))
print(p.get(4,1))
print(p.get(7,0))
print(p.get(7,1))
print(p.get(7,2))
print(p.get(7,3))
print(p.get(7,4))
print(p.get(2,5))
print(p.get(4,0)+p.get(7,5))
# Out:
# 9
# 3
# 3
# 0
# 1
# 2
# 3
# 4
# 1
# 8

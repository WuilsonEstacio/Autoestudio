# %%
# este si corre pero no qui lo correl en  https://repl.it/repls/QuirkyBriefLivecd
import numpy as np
import matplotlib.pyplot as plt
import pandas
import math
import matplotlib


v = 40
A = 55.845 # para hierro
a = 0.6
r = 1.25
R = r*A**(0.3333)

# Función 1.
def f1(x):
    return -v/(1+np.exp((x-R)/a))

x = np.array(np.array(range(-20,20)))
y = f1(x)
print(y)


def move_spines():
    """Esta funcion divide pone al eje y en el valor 
    0 de x para dividir claramente los valores positivos y
    negativos."""
    fix, ax = plt.subplots()
    for spine in ["left", "bottom"]:
        ax.spines[spine].set_position("zero")
    
    for spine in ["right", "top"]:
        ax.spines[spine].set_color("none")
    
    return ax

x = np.linspace(-20, 18, num=30)


ax = move_spines()
ax.grid()
ax.plot(x, f1(x))
plt.title(r"Grafico de $f1(x)$")
plt.ylabel('f1(x)')
plt.xlabel('x')
plt.show()
# Out:
# [-4.00000000e+01 -4.00000000e+01 -4.00000000e+01 -4.00000000e+01
#  -4.00000000e+01 -4.00000000e+01 -4.00000000e+01 -4.00000000e+01
#  -4.00000000e+01 -4.00000000e+01 -4.00000000e+01 -4.00000000e+01
#  -4.00000000e+01 -3.99999999e+01 -3.99999994e+01 -3.99999967e+01
#  -3.99999823e+01 -3.99999061e+01 -3.99995028e+01 -3.99973679e+01
#  -3.99860683e+01 -3.99263488e+01 -3.96131138e+01 -3.80333248e+01
#  -3.14027405e+01 -1.63298988e+01 -4.61130444e+00 -9.60806520e-01
#  -1.85078865e-01 -3.50885714e-02 -6.63209400e-03 -1.25280924e-03
#  -2.36631112e-04 -4.46940583e-05 -8.44162486e-06 -1.59441726e-06
#  -3.01146530e-07 -5.68792328e-08 -1.07430994e-08 -2.02910938e-09]

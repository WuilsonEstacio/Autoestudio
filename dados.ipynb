# %%
# juego de dados.
import random
print("primera ronda lanzada")
x=random.choices([1,2,3,4,5,6],k=2)
print(x)
print("suma del valor de los dados ronda1 es :", sum(x))
numero=int(input("Desea lanzar los dados de nuevo (1)si ,(2)no: "))
if (numero==1):
    x=random.choices([1,2,3,4,5,6],k=2)
    print(x)
    print("suma del valor de los dados ronda2 es :", sum(x))
else :
  print("gracias por jugar")
print("¡Hasta la próxima!")
# Out:
# primera ronda lanzada
# [2, 3]
# suma del valor de los dados ronda1 es : 5
# Desea lanzar los dados de nuevo (1)si ,(2)no: 2
# gracias por jugar
# ¡Hasta la próxima!

# %%
# -*- coding: utf-8 -*-
"""Untitled10.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1-7zZxmcloFVmcONDFZq0GRj30zN8DJ6Z
"""

import random

question = input ("Quieres lanzar los dados? Si - No")

while question == "1":

    dado1 = random.randint(1,6)
    dado2 = random.randint(1,6)

    dado1
    dado2
    sumar = dado1 + dado2

    print ("El dado 1 obtuvo:", dado1)
    print ("El dado 2 obtuvo:", dado2)
    print ("La suma de los2 dados es :", sumar)
    question = input ("Lanzar los dados? Si - No")
# Out:
# Quieres lanzar los dados? Si - No1
# El dado 1 obtuvo: 5
# El dado 2 obtuvo: 3
# La suma de los2 dados es : 8
# Lanzar los dados? Si - No1
# El dado 1 obtuvo: 2
# El dado 2 obtuvo: 3
# La suma de los2 dados es : 5
# Lanzar los dados? Si - No1
# El dado 1 obtuvo: 2
# El dado 2 obtuvo: 1
# La suma de los2 dados es : 3
# Lanzar los dados? Si - No2

# %%
import random
import os
import time 
def tirada_dados():#fUNCION PARA LANZAR LOS DADOS ALEATORIAMENTE
    dados=random.choices([1,2,3,4,5,6],k=2)
    dado_1=dados[0]
    dado_2=dados[1]
    suma=dado_1+dado_2
    print()
    print("EL VALOR DEL PRIMER DADO ES:"+"\033[1;33;41m",dado_1,'\033[0;m')
    print("EL VALOR DEL SEGUNDO DADO ES:"+"\033[1;33;41m",dado_2,'\033[0;m')
    print()
    print("LA SUMA DE AMBOS DADOS ES: "+"\033[1;33;42m",suma,'\033[0;m')
tecla="S"
os.system('cls')
print()
tecla=input("ESTAS LISTO? PRESIONA ENTER PARA LA PRIMERA TIRADA DE DADOS:")
while (tecla !="N"):
    print() 
    print("ESTA ES TU TIRADA:")
    tirada_dados() 
    print()
    print()
    tecla= input("PRESIONA ENTER PARA LANZAR OTRA VEZ, O N+ENTER PARA SALIR: ") 
    os.system('cls')
else:
    print()
    print()
    print('GRACIAS POR JUGAR!, VUELVE PRONTO!!')
    time.sleep(3)

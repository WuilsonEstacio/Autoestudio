# %%
archivo=open("/t1.txt","rt")
  print(archivo.read())
"hola %s " % archivo
# Out:
#   File "<ipython-input-20-0e7df172ea26>", line 2
#     print(archivo.read())
#     ^
# IndentationError: unexpected indent

# %%
with open("/t1.txt","r+") as archivo:
  archivo.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-17-d203e408ba53> in <module>()
#       1 with open("/t1.txt","r+") as archivo:
# ----> 2   archivo.read()
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfa in position 46: invalid start byte

# %%
archivo="""Ahora que has visto el proceso por el cual comúnmente se 
formula y evalúa unproyecto, te invito a que realices la"
 siguiente lectura en donde ahondaré en la manera en 
la que se deben identificar los elementos claves a 
tener en cuenta para que una idea sea evaluada 
exitosamente y logre pasar del proceso de pre 
inversión al proceso de inversión, enmarcado en
el paso del plano de las ideas al plano de las acciones.

Para la mayoría de proyectos existe un esquema generalizado
 para desarrollar la preparación y evaluación de un proyecto.
 Este proceso, denominado como estudio de viabilidad, puede 
enmarcarse bajo cierto algoritmo el cual es adaptable a casi
 cualquier proyecto. A partir de este estudio buscaremos
 responder la pregunta de si es recomendable realizar cierta 
inversión dados diferentes parámetros en el contexto en el
 que se va a desarrollar el proyecto; lo cual proveerá 
algunas herramientas para la toma de decisiones.
"""

name.count('a')
# Out:
# 96

# %%
import math
factorial_10 = str(math.factorial(10))
print(factorial_10)
# Out:
# 3628800

# %%
list(archivo)
# Out:
# ['A',
#  'h',
#  'o',
#  'r',
#  'a',
#  ' ',
#  'q',
#  'u',
#  'e',
#  ' ',
#  'h',
#  'a',
#  's',
#  ' ',
#  'v',
#  'i',
#  's',
#  't',
#  'o',
#  ' ',
#  'e',
#  'l',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'c',
#  'e',
#  's',
#  'o',
#  ' ',
#  'p',
#  'o',
#  'r',
#  ' ',
#  'e',
#  'l',
#  ' ',
#  'c',
#  'u',
#  'a',
#  'l',
#  ' ',
#  'c',
#  'o',
#  'm',
#  'ú',
#  'n',
#  'm',
#  'e',
#  'n',
#  't',
#  'e',
#  ' ',
#  's',
#  'e',
#  ' ',
#  '\n',
#  'f',
#  'o',
#  'r',
#  'm',
#  'u',
#  'l',
#  'a',
#  ' ',
#  'y',
#  ' ',
#  'e',
#  'v',
#  'a',
#  'l',
#  'ú',
#  'a',
#  ' ',
#  'u',
#  'n',
#  'p',
#  'r',
#  'o',
#  'y',
#  'e',
#  'c',
#  't',
#  'o',
#  ',',
#  ' ',
#  't',
#  'e',
#  ' ',
#  'i',
#  'n',
#  'v',
#  'i',
#  't',
#  'o',
#  ' ',
#  'a',
#  ' ',
#  'q',
#  'u',
#  'e',
#  ' ',
#  'r',
#  'e',
#  'a',
#  'l',
#  'i',
#  'c',
#  'e',
#  's',
#  ' ',
#  'l',
#  'a',
#  '"',
#  '\n',
#  ' ',
#  's',
#  'i',
#  'g',
#  'u',
#  'i',
#  'e',
#  'n',
# ...

# %%
import csv
a_list = ['Pedro', 'Florencia', 'Matías', 'Jorge', 'María', 'Inés']

with open('ruta.csv','a') as csvfile:
  write=csv.writer(csvfile)  # crea un obeto de escritorio
  write.writerow(a_list)
# Guardar un archivo csv con el contenido de la variable a_lis

# %%
import csv

reader = csv.reader(['Hola|, Mundo', 'Python'], escapechar='|')

file_content = list(reader)
print(file_content)
# Out:
# [['Hola, Mundo'], ['Python']]
